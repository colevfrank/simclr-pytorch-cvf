# %% [markdown]
# Notebook for running scripts in the simclr-pytorch repo on Google Colab

# %%
# Mount google drive
from google.colab import drive
ROOT = "/content/drive"
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# cd to /Repo
# %cd drive/MyDrive/Repos/simclr-pytorch-cvf/
# %pwd
# Out:
# /content/drive/MyDrive/Repos/simclr-pytorch-cvf
# '/content/drive/MyDrive/Repos/simclr-pytorch-cvf'

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...

# %%
# !conda --version
# Out:
# conda 4.14.0

# %%
# %cd drive/MyDrive/Repos/simclr-pytorch-cvf/
# !conda env create -f environment.yml
# Out:
# /content/drive/MyDrive/Repos/simclr-pytorch-cvf
# done
# done
#
# Downloading and Extracting Packages
# pickleshare-0.7.5    | 13 KB     | : 100% 1.0/1 [00:00<00:00,  7.20it/s]
# zlib-1.2.11          | 103 KB    | : 100% 1.0/1 [00:00<00:00, 13.51it/s]
# libuv-1.40.0         | 736 KB    | : 100% 1.0/1 [00:00<00:00, 10.65it/s]
# libpng-1.6.37        | 278 KB    | : 100% 1.0/1 [00:00<00:00, 11.40it/s]
# pillow-8.0.1         | 621 KB    | : 100% 1.0/1 [00:00<00:00,  7.30it/s]
# python-dateutil-2.8. | 215 KB    | : 100% 1.0/1 [00:00<00:00, 14.06it/s]
# pygments-2.7.3       | 676 KB    | : 100% 1.0/1 [00:00<00:00,  5.87it/s]
# threadpoolctl-2.1.0  | 17 KB     | : 100% 1.0/1 [00:00<00:00, 15.85it/s]
# intel-openmp-2020.2  | 786 KB    | : 100% 1.0/1 [00:00<00:00, 13.39it/s]
# scikit-learn-0.23.2  | 5.0 MB    | : 100% 1.0/1 [00:01<00:00,  1.27s/it]
# ipython-7.16.1       | 999 KB    | : 100% 1.0/1 [00:00<00:00,  3.13it/s]
# jedi-0.17.2          | 919 KB    | : 100% 1.0/1 [00:00<00:00,  2.07it/s]
# zstd-1.4.5           | 619 KB    | : 100% 1.0/1 [00:00<00:00,  8.38it/s]
# libffi-3.3           | 50 KB     | : 100% 1.0/1 [00:00<00:00, 15.86it/s]
# numpy-1.19.2         | 22 KB     | : 100% 1.0/1 [00:00<00:00, 10.25it/s]
# yaml-0.2.5           | 75 KB     | : 100% 1.0/1 [00:00<00:00, 23.24it/s]
# filelock-3.0.12      | 13 KB     | : 100% 1.0/1 [00:00<00:00, 28.43it/s]
# prompt-toolkit-3.0.8 | 248 KB    | : 100% 1.0/1 [00:00<00:00, 10.33it/s]
# readline-8.0         | 356 KB    | : 100% 1.0/1 [00:00<00:00, 13.58it/s]
# typing_extensions-3. | 28 KB     | : 100% 1.0/1 [00:00<00:00, 15.47it/s]
# joblib-0.17.0        | 206 KB    | : 100% 1.0/1 [00:00<00:00,  9.10it/s]
# olefile-0.46         | 48 KB     | : 100% 1.0/1 [00:00<00:00, 15.57it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 15.39it/s]
# xz-5.2.5             | 341 KB    | : 100% 1.0/1 [00:00<00:00, 14.55it/s]
# libtiff-4.1.0        | 449 KB    | : 100% 1.0/1 [00:00<00:00, 10.68it/s]
# pyyaml-5.3.1         | 180 KB    | : 100% 1.0/1 [00:00<00:00, 14.28it/s]
# sqlite-3.33.0        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00, 11.70it/s]
# pip-20.3.1           | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  3.15it/s]
# pytorch-1.7.0        | 552.4 MB  | : 100% 1.0/1 [01:15<00:00, 75.61s/it]
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 12.60it/s]
# cudatoolkit-10.1.243 | 347.4 MB  | : 100% 1.0/1 [00:05<00:00,  5.71s/it]
# freetype-2.10.4      | 596 KB    | : 100% 1.0/1 [00:00<00:00,  2.41it/s]
# ninja-1.10.2         | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  9.00it/s]
# pexpect-4.8.0        | 53 KB     | : 100% 1.0/1 [00:00<00:00, 16.83it/s]
# mkl_random-1.1.1     | 327 KB    | : 100% 1.0/1 [00:00<00:00, 15.79it/s]
# libedit-3.1.20191231 | 116 KB    | : 100% 1.0/1 [00:00<00:00, 14.55it/s]
# mkl_fft-1.2.0        | 149 KB    | : 100% 1.0/1 [00:00<00:00, 11.29it/s]
# pandas-1.1.3         | 8.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.36it/s]
# libgcc-ng-9.1.0      | 5.1 MB    | : 100% 1.0/1 [00:00<00:00,  4.81it/s]
# mkl-2020.2           | 138.3 MB  | : 100% 1.0/1 [00:04<00:00,  4.02s/it]
# dataclasses-0.7      | 30 KB     | : 100% 1.0/1 [00:00<00:00,  7.56it/s]
# ncurses-6.2          | 817 KB    | : 100% 1.0/1 [00:00<00:00,  2.10it/s]
# mkl-service-2.3.0    | 52 KB     | : 100% 1.0/1 [00:00<00:00, 14.34it/s]
# pytz-2020.4          | 180 KB    | : 100% 1.0/1 [00:00<00:00,  4.77it/s]
# setuptools-51.0.0    | 712 KB    | : 100% 1.0/1 [00:00<00:00,  4.47it/s]
# scipy-1.5.2          | 14.4 MB   | : 100% 1.0/1 [00:00<00:00,  1.42it/s]
# backcall-0.2.0       | 15 KB     | : 100% 1.0/1 [00:00<00:00, 28.69it/s]
# torchaudio-0.7.0     | 9.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.59s/it]
# configargparse-1.2.3 | 34 KB     | : 100% 1.0/1 [00:00<00:00, 16.24it/s]
# six-1.15.0           | 27 KB     | : 100% 1.0/1 [00:00<00:00, 14.81it/s]
# openssl-1.1.1h       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  4.93it/s]
# tabulate-0.8.7       | 40 KB     | : 100% 1.0/1 [00:00<00:00, 11.38it/s]
# libstdcxx-ng-9.1.0   | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  8.62it/s]
# numpy-base-1.19.2    | 4.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.08it/s]
# libgfortran-ng-7.3.0 | 1006 KB   | : 100% 1.0/1 [00:00<00:00, 16.61it/s]
# ipython_genutils-0.2 | 27 KB     | : 100% 1.0/1 [00:00<00:00, 17.62it/s]
# decorator-4.4.2      | 14 KB     | : 100% 1.0/1 [00:00<00:00, 18.29it/s]
# ca-certificates-2020 | 121 KB    | : 100% 1.0/1 [00:00<00:00, 12.80it/s]
# certifi-2020.12.5    | 140 KB    | : 100% 1.0/1 [00:00<00:00, 10.26it/s]
# lcms2-2.11           | 307 KB    | : 100% 1.0/1 [00:00<00:00, 12.09it/s]
# wcwidth-0.2.5        | 29 KB     | : 100% 1.0/1 [00:00<00:00, 25.54it/s]
# tqdm-4.54.1          | 55 KB     | : 100% 1.0/1 [00:00<00:00, 10.96it/s]
# wheel-0.36.1         | 32 KB     | : 100% 1.0/1 [00:00<00:00, 10.98it/s]
# torchvision-0.8.1    | 17.9 MB   | : 100% 1.0/1 [00:02<00:00,  2.42s/it]
# python-3.6.12        | 29.7 MB   | : 100% 1.0/1 [00:01<00:00,  1.06s/it]
# ptyprocess-0.6.0     | 20 KB     | : 100% 1.0/1 [00:00<00:00, 14.86it/s]
# ld_impl_linux-64-2.3 | 568 KB    | : 100% 1.0/1 [00:00<00:00, 22.97it/s]
# jpeg-9b              | 214 KB    | : 100% 1.0/1 [00:00<00:00, 17.13it/s]
# tk-8.6.10            | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  5.05it/s]
# parso-0.7.0          | 72 KB     | : 100% 1.0/1 [00:00<00:00, 15.91it/s]
# traitlets-4.3.3      | 140 KB    | : 100% 1.0/1 [00:00<00:00, 11.86it/s]
# lz4-c-1.9.2          | 175 KB    | : 100% 1.0/1 [00:00<00:00, 12.32it/s]
# done
# done
# done
# \ Ran pip subprocess with arguments:
# ['/usr/local/envs/simclr_pytorch/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/drive/MyDrive/Repos/simclr-pytorch-cvf/condaenv.77pbxeyz.requirements.txt']
# Pip subprocess output:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting diffdist==0.1
#   Downloading diffdist-0.1.tar.gz (4.6 kB)
# Collecting strconv==0.4.2
#   Downloading strconv-0.4.2.tar.gz (3.2 kB)
# Building wheels for collected packages: diffdist, strconv
#   Building wheel for diffdist (setup.py): started
#   Building wheel for diffdist (setup.py): finished with status 'done'
#   Created wheel for diffdist: filename=diffdist-0.1-py3-none-any.whl size=6552 sha256=cbf46cd5916b2e85f6e059f68d56443e61c50b7cd04c6670075d478514b25e80
#   Stored in directory: /root/.cache/pip/wheels/52/78/50/b456b515245007fecf850f6572595d78cafe990d62612dcec8
#   Building wheel for strconv (setup.py): started
#   Building wheel for strconv (setup.py): finished with status 'done'
#   Created wheel for strconv: filename=strconv-0.4.2-py3-none-any.whl size=3748 sha256=2df7b8ed1ac73392fee8e7f41ace25fb99f135ddbc98400bbf7c34a7669a25f1
#   Stored in directory: /root/.cache/pip/wheels/91/98/18/c63ac2df92ba19e9e8ac69bc14707afcd467c1e360f4b16434
# Successfully built diffdist strconv
# Installing collected packages: strconv, diffdist
# Successfully installed diffdist-0.1 strconv-0.4.2
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate simclr_pytorch
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /usr/local
# simclr_pytorch           /usr/local/envs/simclr_pytorch

# %%
# run this in CLI 
# !source activate /usr/local/envs/simclr_pytorch

# %%
# !git pull

# %%
# run this in CLI for pre-training
# !python train.py --config configs/cifar_train_epochs60_bs256.yaml

# run this in CLI for linear classifier training
python train.py --config configs/cifar_eval.yaml --encoder_ckpt logs/exman-train.py/runs/000004/checkpoint-12000.pth.tar
# Out:
# Traceback (most recent call last):
#   File "train.py", line 5, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'

# %%
# %pwd
# Out:
# '/content'
